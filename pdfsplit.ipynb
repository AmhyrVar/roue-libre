# %%
import fitz  # PyMuPDF

# Spécifiez le chemin vers le fichier PDF
pdf_path = "pilly/pilly.pdf"
output_path = "pilly/extracted_pages_pymupdf.pdf"

# Ouvrir le document PDF
pdf_document = fitz.open(pdf_path)

# Créer un nouveau document PDF pour les pages extraites
pdf_writer = fitz.open()

# Extraire les pages 11 à 14
for page_num in range(10, 14):
    page = pdf_document.load_page(page_num)
    pdf_writer.insert_pdf(pdf_document, from_page=page_num, to_page=page_num)

# Enregistrer les pages extraites dans un nouveau fichier PDF
pdf_writer.save(output_path)
pdf_writer.close()
pdf_document.close()

# %%
import fitz  # PyMuPDF

# Spécifiez le chemin vers le fichier PDF
pdf_path = "pilly/pilly.pdf"
output_dir = "pilly/"

# Ouvrir le document PDF
pdf_document = fitz.open(pdf_path)

# Dictionnaire des chapitres avec les titres et les pages correspondantes
chapters = {
    "Fièvre aiguë. Examen clinique en infectiologie tropicale": (186, 191),
    "Eruptions fébriles": (192, 200),
    "Syndromes septiques et choc septique": (201, 205),
    "Fièvres hémorragiques virales": (206, 216),
    "Fièvres prolongées, granulomatoses hépatiques": (217, 222),
    "Splénomégalies infectieuses": (223, 225),
    "Adénopathies infectieuses": (226, 229),
    "Infections buccales": (230, 239),
    "Infections respiratoires hautes : rhino-pharyngites, angines, sinusites, otites, infections ORL tropicales": (240, 250),
    "Infections respiratoires basses": (251, 273),
    "Pleurésies infectieuses": (274, 279),
    "Diarrhées infectieuses": (280, 292),
    "Infections et toxi-infections d’origine alimentaire": (293, 298),
    "Douleurs abdominales fébriles": (299, 305),
    "Ascites infectieuses": (306, 308),
    "Ictères fébriles": (309, 312),
    "Infections urinaires communautaires": (313, 318),
    "Épidémiologie des IST": (319, 321),
    "Écoulement urétral chez l’homme": (322, 326),
    "Écoulement vaginal": (327, 329),
    "Ulcérations génitales": (330, 340),
    "Infections pelviennes chez la femme": (341, 344),
    "Péricardites infectieuses": (345, 349),
    "Myocardites": (350, 352),
    "Endocardites infectieuses": (353, 361),
    "Méningites": (362, 374),
    "Méningo-encéphalites": (375, 380),
    "Infections oculaires": (381, 394),
    "Infections par inoculation, morsures (hors rage et envenimations)": (395, 398),
    "Envenimations": (399, 411),
    "Infections de la peau, des tissus mous et des muscles": (412, 430),
    "Infections ostéo-articulaires": (431, 440),
    "Hyperéosinophilie, interprétation de la numération sanguine et syndrome mononucléosique": (441, 449),
    "Tuberculose": (450, 463),
    "Lèpre": (464, 471),
    "Ulcère de Buruli, infection à Mycobacterium ulcerans": (472, 478),
    "Tréponématoses endémiques": (479, 488),
    "Streptococcies et rhumatisme articulaire aigu": (489, 492),
    "Staphylococcies": (493, 498),
    "Tétanos": (499, 506),
    "Diphtérie": (507, 517),
    "Coqueluche": (518, 522),
    "Fièvre typhoïde": (523, 527),
    "Salmonelloses non typhiques": (528, 530),
    "Listériose": (531, 534),
    "Infection par Helicobacter pylori": (535, 542),
    "Shigelloses": (543, 544),
    "Choléra": (545, 548),
    "Peste": (549, 552),
    "Charbon": (553, 557),
    "Brucellose": (558, 562),
    "Leptospiroses": (563, 568),
    "Fièvres récurrentes": (569, 576),
    "Rickettsioses": (577, 585),
    "Fièvre Q": (586, 590),
    "Bartonelloses": (591, 597),
    "Morve": (598, 599),
    "Mélioïdose": (600, 604),
    "Actinomycoses - Nocardioses": (605, 609),
    "Infection par le VIH et SIDA": (610, 665),
    "Infection par HTLV": (666, 667),
    "Hépatites virales": (668, 684),
    "Infections par les entérovirus": (685, 694),
    "Viroses respiratoires": (695, 711),
    "Herpès (HSV-1, HSV-2)": (712, 715),
    "Varicelle, zona": (716, 719),
    "Infections par le CMV et l’EBV": (720, 726),
    "Poxviroses": (727, 732),
    "Infections par les papillomavirus (HPV)": (733, 738),
    "Arboviroses tropicales": (739, 765),
    "Infections par les Filovirus, les Arenavirus et les Hantavirus": (766, 778),
    "Rage": (779, 785),
    "Paludisme": (786, 801),
    "Parasitoses intestinales": (802, 811),
    "Amoebose tissulaire": (812, 816),
    "Gale": (817, 820),
    "Tungose": (821, 823),
    "Myiases": (824, 829),
    "Filarioses": (830, 844),
    "Bilharzioses ou schistosomoses": (845, 855),
    "Trypanosomose humaine africaine": (856, 864),
    "Trypanosomose américaine ou maladie de Chagas": (865, 872),
    "Leishmanioses": (873, 882),
    "Migrations larvaires et impasses parasitaires": (883, 899),
    "Distomatoses": (900, 906),
    "Toxoplasmose": (907, 910),
    "Mycoses profondes tropicales": (911, 942),
    "Mycétomes": (943, 945),
    "Teignes": (946, 951),
    "Infection et grossesse (hors VIH)": (952, 957),
    "Infections puerpérales": (958, 960),
    "Infections néonatales": (961, 966),
    "Prise en charge intégrée des maladies de l’enfance (PCIME)": (967, 970),
    "Infections et drépanocytose": (971, 976),
    "Infections et diabète": (977, 982),
    "Infections chez les usagers de drogues": (983, 986),
    "Infections chez le neutropénique": (987, 989),
    "Infections associées aux soins": (990, 994),
    "Accidents d’exposition sexuelle ou au sang (AES)": (995, 1004),
    "Infections transmises par la transfusion de sang ou de ses dérivés": (1005, 1009),
    "Infections tropicales et cancers": (1010, 1013),
    "Prévention et prise en charge des infections chez les migrants": (1014, 1022)
}

# Extraire et enregistrer chaque chapitre comme fichier PDF séparé
for chapter, (start_page, end_page) in chapters.items():
    pdf_writer = fitz.open()
    for page_num in range(start_page - 1, end_page):  # Les numéros de page sont décalés de 1
        page = pdf_document.load_page(page_num)
        pdf_writer.insert_pdf(pdf_document, from_page=page_num, to_page=page_num)
    pdf_writer.save(f"{output_dir}{chapter}.pdf")
    pdf_writer.close()

pdf_document.close()
# Out:
# skipping bad link / annot item 0.

# %%
import fitz  # PyMuPDF
from openai import OpenAI
import os
import json


# Initialisation de l'API OpenAI
openai_api_key = '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'
openai = OpenAI(api_key=openai_api_key)

# Dossier contenant les PDF
pdf_folder = "test/"

# Liste des fichiers PDF dans le dossier
pdf_files = [f for f in os.listdir(pdf_folder) if f.endswith('.pdf')]

# Fonction pour extraire le texte d'un PDF
def extract_text_from_pdf(pdf_path):
    pdf_document = fitz.open(pdf_path)
    text = ""
    for page_num in range(len(pdf_document)):
        page = pdf_document.load_page(page_num)
        text += page.get_text()
    pdf_document.close()
    return text

# Few-shot exemples pour le prompt
few_shot_examples = """
{
    "qtype": "symptômes",
    "Question": "Quels sont les symptômes de la brucellose aiguë septicémique ?",
    "Answer": "Les symptômes de la brucellose aiguë septicémique incluent une fièvre ondulante sudoro-algique, des douleurs musculaires et articulaires, des courbatures, des sueurs abondantes (nocturnes), et une asthénie. L'examen clinique peut révéler une hépatomégalie et une splénomégalie dans 25 à 40 % des cas, ainsi que quelques adénopathies périphériques et des râles bronchiques."
},
{
    "qtype": "diagnostic",
    "Question": "Comment diagnostique-t-on la brucellose ?",
    "Answer": "Le diagnostic de la brucellose repose sur des éléments d'orientation comme le contexte épidémiologique et la leuconeutropénie habituelle associée à un syndrome inflammatoire modéré. Les examens spécifiques incluent les hémocultures, la recherche du germe dans des liquides biologiques ou des prélèvements tissulaires, la sérologie avec différents tests (séroagglutination de Wright, fixation du complément, card-test, IFI, ELISA), et la technique d’amplification génique (PCR)."
},
"""

# Fonction pour générer des entrées à partir du texte extrait
def generate_entries_from_pdf_text(pdf_text):
    prompt = f"""
    {few_shot_examples}
    En te basant sur le PDF que je t'ai donné, génère-moi des entrées sur les traitements, symptômes, diagnostic, épidémiologie, etc. Ne te base que sur le PDF que je t'ai donné, génère-moi 60 entrées.
    PDF Content:
    {pdf_text}
    """
    response = openai.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ],
        max_tokens=1500,
        n=1,
        stop=None,
        temperature=0
    )
    return response.choices[0].message['content']

# Processus principal pour traiter chaque PDF
for pdf_file in pdf_files:
    pdf_path = os.path.join(pdf_folder, pdf_file)
    pdf_text = extract_text_from_pdf(pdf_path)
    entries = generate_entries_from_pdf_text(pdf_text)
    json_output = f"{pdf_folder}{os.path.splitext(pdf_file)[0]}_entries.json"
    
    # Conversion en format JSON
    entries_list = [json.loads(entry) for entry in entries.split("\n") if entry.strip()]
    with open(json_output, 'w', encoding='utf-8') as f:
        json.dump(entries_list, f, ensure_ascii=False, indent=4)

    print(f"Entries for {pdf_file} generated and saved to {json_output}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 66
#      64 pdf_path = os.path.join(pdf_folder, pdf_file)
#      65 pdf_text = extract_text_from_pdf(pdf_path)
# ---> 66 entries = generate_entries_from_pdf_text(pdf_text)
#      67 json_output = f"{pdf_folder}{os.path.splitext(pdf_file)[0]}_entries.json"
#      69 # Conversion en format JSON
#
# Cell In[19], line 60, in generate_entries_from_pdf_text(pdf_text)
#      43 prompt = f"""
#      44 {few_shot_examples}
#      45 En te basant sur le PDF que je t'ai donné, génère-moi des entrées sur les traitements, symptômes, diagnostic, épidémiologie, etc. Ne te base que sur le PDF que je t'ai donné, génère-moi 60 entrées.
#      46 PDF Content:
#      47 {pdf_text}
#      48 """
#      49 response = openai.chat.completions.create(
#      50     model="gpt-4o",
#      51     messages=[
#    (...)
#      58     temperature=0
#      59 )
# ---> 60 return response.choices[0].message['content']
#
# TypeError: 'ChatCompletionMessage' object is not subscriptable

# %%
import fitz  # PyMuPDF
from openai import OpenAI
import os
import json


# Initialisation de l'API OpenAI
openai_api_key = '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'
openai = OpenAI(api_key=openai_api_key)

# Dossier contenant les PDF
pdf_folder = "test/"

# Liste des fichiers PDF dans le dossier
pdf_files = [f for f in os.listdir(pdf_folder) if f.endswith('.pdf')]

# Fonction pour extraire le texte d'un PDF
def extract_text_from_pdf(pdf_path):
    pdf_document = fitz.open(pdf_path)
    text = ""
    for page_num in range(len(pdf_document)):
        page = pdf_document.load_page(page_num)
        text += page.get_text()
    pdf_document.close()
    return text

# Few-shot exemples pour le prompt
few_shot_examples = """
{
    "qtype": "symptômes",
    "Question": "Quels sont les symptômes de la brucellose aiguë septicémique ?",
    "Answer": "Les symptômes de la brucellose aiguë septicémique incluent une fièvre ondulante sudoro-algique, des douleurs musculaires et articulaires, des courbatures, des sueurs abondantes (nocturnes), et une asthénie. L'examen clinique peut révéler une hépatomégalie et une splénomégalie dans 25 à 40 % des cas, ainsi que quelques adénopathies périphériques et des râles bronchiques."
},
{
    "qtype": "diagnostic",
    "Question": "Comment diagnostique-t-on la brucellose ?",
    "Answer": "Le diagnostic de la brucellose repose sur des éléments d'orientation comme le contexte épidémiologique et la leuconeutropénie habituelle associée à un syndrome inflammatoire modéré. Les examens spécifiques incluent les hémocultures, la recherche du germe dans des liquides biologiques ou des prélèvements tissulaires, la sérologie avec différents tests (séroagglutination de Wright, fixation du complément, card-test, IFI, ELISA), et la technique d’amplification génique (PCR)."
},
"""

# Fonction pour générer des entrées à partir du texte extrait
def generate_entries_from_pdf_text(pdf_text):
    prompt = f"""
    {few_shot_examples}
    En te basant sur le PDF que je t'ai donné, génère-moi un json avec des entrées sur les traitements, symptômes, diagnostic, épidémiologie, etc. Ne te base que sur le PDF que je t'ai donné, génère-moi 60 entrées.
    Ne réponds qu'avec le Json.
    PDF Content:
    {pdf_text}
    """
    response = openai.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ],
        max_tokens=1500,
        n=1,
        stop=None,
        temperature=0
    )
    return response.choices[0].message.content

# Processus principal pour traiter chaque PDF
for pdf_file in pdf_files:
    pdf_path = os.path.join(pdf_folder, pdf_file)
    pdf_text = extract_text_from_pdf(pdf_path)
    entries = generate_entries_from_pdf_text(pdf_text)
    print(entries)
    json_output = f"{pdf_folder}{os.path.splitext(pdf_file)[0]}_entries.json"
    
    # Conversion en format JSON
    entries_list = [json.loads(entry) for entry in entries.split("\n") if entry.strip()]
    with open(json_output, 'w', encoding='utf-8') as f:
        json.dump(entries_list, f, ensure_ascii=False, indent=4)

    print(f"Entries for {pdf_file} generated and saved to {json_output}")
# Out:
# ```json
# [
#     {
#         "qtype": "épidémiologie",
#         "Question": "Quelle est l'incidence annuelle de la listériose en France ?",
#         "Answer": "L'incidence annuelle de la listériose en France en 2019 était de 5,6 par million d'habitants (300 à 400 cas/an)."
#     },
#     {
#         "qtype": "épidémiologie",
#         "Question": "Quels sont les principaux réservoirs de Listeria ?",
#         "Answer": "Listeria réside dans l'environnement et peut séjourner dans le tube digestif des animaux et des hommes (1 à 10 % de portage fécal)."
#     },
#     {
#         "qtype": "épidémiologie",
#         "Question": "Quels aliments sont souvent associés à la transmission de la listériose ?",
#         "Answer": "Les crudités, le lait et les produits dérivés non pasteurisés tels que les fromages à pâte molle, les produits carnés tels que la charcuterie, et les produits de la mer."
#     },
#     {
#         "qtype": "épidémiologie",
#         "Question": "Quels sont les groupes à risque pour la listériose ?",
#         "Answer": "Les nouveau-nés, les personnes dont l'immunité est altérée (> 65 ans, cancer, maladies hépatiques, transplantés, traitement par anticorps monoclonaux, corticothérapie, hémodialysés), et les personnes infectées par le VIH."
#     },
#     {
#         "qtype": "physiopathologie",
#         "Question": "Comment Listeria monocytogenes franchit-elle la barrière digestive ?",
#         "Answer": "Listeria monocytogenes franchit la barrière digestive via les plaques de Peyer et se multiplie dans le cytosol des cellules, macrophages et monocytes intestinaux."
#     },
#     {
#         "qtype": "physiopathologie",
#         "Question": "Quels sont les principaux types d'infections causées par Listeria monocytogenes chez l'adulte ?",
#         "Answer": "Les principaux types d'infections sont la bactériémie isolée ou avec localisations viscérales (abcès), l'atteinte du système nerveux (méningite, méningo-encéphalite, rhombencéphalite), et l'infection materno-fœtale."
#     },
#     {
#         "qtype": "physiopathologie",
#         "Question": "Comment se manifeste la listériose chez le patient immunocompétent ?",
#         "Answer": "Chez le patient immunocompétent, la listériose se manifeste par une gastro-entérite fébrile rapidement résolutive spontanément."
#     },
#     {
#         "qtype": "clinique",
#         "Question": "Quels sont les symptômes des formes septicémiques de la listériose ?",
#         "Answer": "Les formes septicémiques se manifestent par un syndrome infectieux non spécifique associant fièvre élevée, frissons, algies multiples, d'apparition brutale."
#     },
#     {
#         "qtype": "clinique",
#         "Question": "Quels sont les symptômes des formes neuroméningées de la listériose ?",
#         "Answer": "Les formes neuroméningées peuvent inclure un syndrome méningé d'apparition aiguë ou subaiguë, des signes neurologiques variés, des troubles de la vigilance, des convulsions, et des déficits par atteinte des fibres longues."
#     },
#     {
#         "qtype": "clinique",
#         "Question": "Quels sont les symptômes de la listériose chez la femme enceinte ?",
#         "Answer": "La listériose chez la femme enceinte se présente souvent sous l'aspect de troubles digestifs non spécifiques, une fièvre isolée et passagère d'allure « virale », ou plus rarement sous la forme d'un syndrome infectieux plus marqué (fièvre, frissons persistant plusieurs jours)."
#     },
#     {
#         "qtype": "diagnostic",
#         "Question": "Quels prélèvements sont utilisés pour le diagnostic de la listériose ?",
#         "Answer": "Les hémocultures, le liquide cérébrospinal, et d'autres prélèvements locaux en cas de localisation secondaire (liquide d'abcès, ponction articulaire ou de disque intervertébral)."
#     },
#     {
#         "qtype": "diagnostic",
#         "Question": "Quel est l'intérêt de la biologie moléculaire dans le diagnostic de la listériose ?",
#         "Answer": "La biologie moléculaire, notamment la technique de PCR, permet la recherche de Listeria, surtout dans le liquide cérébrospinal et en cas d'antibiothérapie préalable."
#     },
#     {
#         "qtype": "traitement",
#         "Question": "Quel est le traitement recommandé pour les atteintes neuroméningées de la listériose ?",
#         "Answer": "Amoxicilline ou ampicilline (200 mg/kg/j) en 4 à 6 injections pendant 21 jours, associé à la gentamicine 3 à 5 mg/kg au cours des 3-5 premiers jours surtout chez l'immunodéprimé."
#     },
#     {
#         "qtype": "traitement",
#         "Question": "Quel est le traitement recommandé pour les bactériémies et les listérioses néonatales ?",
#         "Answer": "Amoxicilline ou ampicilline + aminoside pendant 15 jours."
#     },
#     {
#         "qtype": "traitement",
#         "Question": "Quel est le traitement recommandé pour la listériose de la femme enceinte (méningite exclue) ?",
#         "Answer": "Amoxicilline (100 mg/kg/j) ou ampicilline pendant 2 à 3 semaines. Un aminoside est généralement déconseillé, mais dans les formes sévères la gentamicine peut être donnée pendant 3 à 5 jours."
#     },
#     {
#         "qtype": "traitement",
#         "Question": "Quel est le traitement en cas d'allergie à la pénicilline pour les atteintes neuroméningées de la listériose ?",
#         "Answer": "Le cotrimoxazole IV (TMP : 6 à 8 mg/kg ; SMZ : 30 à 40 mg/kg) pendant 21 jours est habituellement prescrit. L'association à la rifampicine est parfois proposée sans que son intérêt ait été démontré."
#     },
#     {
#         "qtype": "évolution",
#         "Question": "Quel est le pronostic de la listériose neuroméningée ?",
#         "Answer": "Le pronostic des atteintes neuroméningées est sévère avec une mortalité de 25 à 35 % des cas chez les malades de moins d'1 mois, de plus de 50 ans et les
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[31], line 72
#      69 json_output = f"{pdf_folder}{os.path.splitext(pdf_file)[0]}_entries.json"
#      71 # Conversion en format JSON
# ---> 72 entries_list = [json.loads(entry) for entry in entries.split("\n") if entry.strip()]
#      73 with open(json_output, 'w', encoding='utf-8') as f:
#      74     json.dump(entries_list, f, ensure_ascii=False, indent=4)
#
# Cell In[31], line 72, in <listcomp>(.0)
#      69 json_output = f"{pdf_folder}{os.path.splitext(pdf_file)[0]}_entries.json"
#      71 # Conversion en format JSON
# ---> 72 entries_list = [json.loads(entry) for entry in entries.split("\n") if entry.strip()]
#      73 with open(json_output, 'w', encoding='utf-8') as f:
#      74     json.dump(entries_list, f, ensure_ascii=False, indent=4)
#
# File d:\Envs\envs\cudaenv\lib\json\__init__.py:357, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352     del kw['encoding']
#     354 if (cls is None and object_hook is None and
#     355         parse_int is None and parse_float is None and
#     356         parse_constant is None and object_pairs_hook is None and not kw):
# --> 357     return _default_decoder.decode(s)
#     358 if cls is None:
#     359     cls = JSONDecoder
#
# File d:\Envs\envs\cudaenv\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File d:\Envs\envs\cudaenv\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# Cleaning du prompt pour avoir un json valid

# %%
import fitz  # PyMuPDF
from openai import OpenAI
import os
import json
import tiktoken


# Initialisation de l'API OpenAI
openai_api_key = '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'
openai = OpenAI(api_key=openai_api_key)

# Dossier contenant les PDF
pdf_folder = "test/"

# Liste des fichiers PDF dans le dossier
pdf_files = [f for f in os.listdir(pdf_folder) if f.endswith('.pdf')]

def num_tokens(text):
    encoding = tiktoken.encoding_for_model("gpt-4o")
    return len(encoding.encode(text))

# Fonction pour extraire le texte d'un PDF
def extract_text_from_pdf(pdf_path):
    pdf_document = fitz.open(pdf_path)
    text = ""
    for page_num in range(len(pdf_document)):
        page = pdf_document.load_page(page_num)
        text += page.get_text()
    pdf_document.close()
    return text

# Few-shot exemples pour le prompt
few_shot_examples = """
{
    "qtype": "symptômes",
    "Question": "Quels sont les symptômes de la brucellose aiguë septicémique ?",
    "Answer": "Les symptômes de la brucellose aiguë septicémique incluent une fièvre ondulante sudoro-algique, des douleurs musculaires et articulaires, des courbatures, des sueurs abondantes (nocturnes), et une asthénie. L'examen clinique peut révéler une hépatomégalie et une splénomégalie dans 25 à 40 % des cas, ainsi que quelques adénopathies périphériques et des râles bronchiques."
},
{
    "qtype": "diagnostic",
    "Question": "Comment diagnostique-t-on la brucellose ?",
    "Answer": "Le diagnostic de la brucellose repose sur des éléments d'orientation comme le contexte épidémiologique et la leuconeutropénie habituelle associée à un syndrome inflammatoire modéré. Les examens spécifiques incluent les hémocultures, la recherche du germe dans des liquides biologiques ou des prélèvements tissulaires, la sérologie avec différents tests (séroagglutination de Wright, fixation du complément, card-test, IFI, ELISA), et la technique d’amplification génique (PCR)."
},
"""

# Fonction pour générer des entrées à partir du texte extrait
def generate_entries_from_pdf_text(pdf_text):
    prompt = f"""
    {few_shot_examples}
    En te basant sur le PDF que je t'ai donné, génère-moi un json valide avec des entrées sur les traitements, symptômes, diagnostic, épidémiologie, etc. Ne te base que sur le PDF que je t'ai donné, génère-moi 30 entrées.
    PDF Content:
    {pdf_text}
    """
    response = openai.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ],
        max_tokens=4096,
        n=1,
        stop=None,
        temperature=0
    )

    generated = response.choices[0].message.content
    tokens_used = num_tokens(prompt + generated)
    generated_tokens = num_tokens(generated)
    prompt_tokens = num_tokens(prompt)
    print(f"Tokens used: {tokens_used} with generated : {generated_tokens} and prompt : {prompt_tokens}")
    return generated

# Processus principal pour traiter chaque PDF
for pdf_file in pdf_files:
    pdf_path = os.path.join(pdf_folder, pdf_file)
    pdf_text = extract_text_from_pdf(pdf_path)
    entries = generate_entries_from_pdf_text(pdf_text)
    print(entries)
    json_output = f"{pdf_folder}{os.path.splitext(pdf_file)[0]}_entries.json"
    
    # Conversion en format JSON
    entries_list = [json.loads(entry) for entry in entries.split("\n") if entry.strip()]
    with open(json_output, 'w', encoding='utf-8') as f:
        json.dump(entries_list, f, ensure_ascii=False, indent=4)

    print(f"Entries for {pdf_file} generated and saved to {json_output}")

# %%
import fitz  # PyMuPDF
from openai import OpenAI
import os
import json
import tiktoken


# Initialisation de l'API OpenAI
openai_api_key = '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'
openai = OpenAI(api_key=openai_api_key)

# Dossier contenant les PDF
pdf_folder = "test/"

# Liste des fichiers PDF dans le dossier
pdf_files = [f for f in os.listdir(pdf_folder) if f.endswith('.pdf')]

def num_tokens(text):
    encoding = tiktoken.encoding_for_model("gpt-4o")
    return len(encoding.encode(text))

# Fonction pour extraire le texte d'un PDF
def extract_text_from_pdf(pdf_path):
    pdf_document = fitz.open(pdf_path)
    text = ""
    for page_num in range(len(pdf_document)):
        page = pdf_document.load_page(page_num)
        text += page.get_text()
    pdf_document.close()
    return text

# Few-shot exemples pour le prompt
few_shot_examples = """
{
    "qtype": "symptômes",
    "Question": "Quels sont les symptômes de la brucellose aiguë septicémique ?",
    "Answer": "Les symptômes de la brucellose aiguë septicémique incluent une fièvre ondulante sudoro-algique, des douleurs musculaires et articulaires, des courbatures, des sueurs abondantes (nocturnes), et une asthénie. L'examen clinique peut révéler une hépatomégalie et une splénomégalie dans 25 à 40 % des cas, ainsi que quelques adénopathies périphériques et des râles bronchiques."
},
{
    "qtype": "diagnostic",
    "Question": "Comment diagnostique-t-on la brucellose ?",
    "Answer": "Le diagnostic de la brucellose repose sur des éléments d'orientation comme le contexte épidémiologique et la leuconeutropénie habituelle associée à un syndrome inflammatoire modéré. Les examens spécifiques incluent les hémocultures, la recherche du germe dans des liquides biologiques ou des prélèvements tissulaires, la sérologie avec différents tests (séroagglutination de Wright, fixation du complément, card-test, IFI, ELISA), et la technique d’amplification génique (PCR)."
},
"""

# Fonction pour générer des entrées à partir du texte extrait
def generate_entries_from_pdf_text(pdf_text):
    # Split the PDF text into two parts
    halfway_point = len(pdf_text) // 2
    pdf_text_part1 = pdf_text[:halfway_point]
    pdf_text_part2 = pdf_text[halfway_point:]
    
    few_shot_examples = """
    # Add your few-shot examples here
    """
    
    def get_response_from_openai(pdf_text_part):
        prompt = f"""
        {few_shot_examples}
        En te basant sur le PDF que je t'ai donné et les few-shot examples, génère-moi un json valide avec des entrées question réponse et qtype sur les traitements, symptômes, diagnostic, épidémiologie, etc. Ne te base que sur le PDF que je t'ai donné, génère-moi 2 entrées.
        Ta réponse ne doit contenir que le Json car elle devra être parsée par json.loads()
        PDF Content:
        {pdf_text_part}
        """
        response = openai.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "You are a helpful assistant."},
                {"role": "user", "content": prompt}
            ],
            max_tokens=4096,
            n=1,
            stop=None,
            temperature=0
        )
        
        return response.choices[0].message.content
    
    # Get responses for both parts of the PDF
    response_part1 = get_response_from_openai(pdf_text_part1)
    response_part2 = get_response_from_openai(pdf_text_part2)
    
    # Calculate token usage for both parts
    total_tokens_used = num_tokens(response_part1) + num_tokens(response_part2)
    print("Response pt1")
    print(response_part1)
    print("Response pt2")
    print(response_part2)
    
    # Merge the generated JSON entries
    generated_entries_part1 = json.loads(response_part1)
    generated_entries_part2 = json.loads(response_part2)
    merged_entries = generated_entries_part1 + generated_entries_part2
    
    # Ensure only 30 entries are returned
    final_entries = merged_entries[:30]
    
    print(f"Tokens used: {total_tokens_used}")
    return json.dumps(final_entries, ensure_ascii=False, indent=2)


# Processus principal pour traiter chaque PDF
for pdf_file in pdf_files:
    pdf_path = os.path.join(pdf_folder, pdf_file)
    pdf_text = extract_text_from_pdf(pdf_path)
    entries = generate_entries_from_pdf_text(pdf_text)
    print(entries)
    json_output = f"{pdf_folder}{os.path.splitext(pdf_file)[0]}_entries.json"
    
    # Conversion en format JSON
    entries_list = [json.loads(entry) for entry in entries.split("\n") if entry.strip()]
    with open(json_output, 'w', encoding='utf-8') as f:
        json.dump(entries_list, f, ensure_ascii=False, indent=4)

    print(f"Entries for {pdf_file} generated and saved to {json_output}")
# Out:
# Response pt1
# ```json
# [
#     {
#         "question": "Quels sont les principaux modes de transmission de la listériose?",
#         "answer": "La transmission de la listériose est essentiellement alimentaire sauf chez la femme enceinte qui transmet au foetus par voie trans-placentaire et au nouveau-né lors du passage dans la filière génitale.",
#         "qtype": "épidémiologie"
#     },
#     {
#         "question": "Quels sont les traitements recommandés pour les formes septicémiques de la listériose?",
#         "answer": "Le traitement par amoxicilline associé à la gentamicine permet une défervescence et une amélioration clinique alors que les céphalosporines sont inactives sur Listeria monocytogenes.",
#         "qtype": "traitements"
#     }
# ]
# ```
# Response pt2
# ```json
# [
#     {
#         "question": "Quels sont les symptômes de la rhombencéphalite dans le cadre de la neurolistériose?",
#         "answer": "La rhombencéphalite se traduit par des troubles de la vigilance, des convulsions et des déficits par atteinte des fibres longues, surtout des derniers nerfs crâniens.",
#         "qtype": "symptômes"
#     },
#     {
#         "question": "Quel est le traitement recommandé pour la listériose de la femme enceinte (méningite exclue)?",
#         "answer": "Le traitement recommandé est l'amoxicilline (100 mg/kg/j) ou l'ampicilline pendant 2 à 3 semaines. Un aminoside est généralement déconseillé, mais dans les formes sévères, la gentamicine peut être donnée pendant 3 à 5 jours.",
#         "qtype": "traitement"
#     }
# ]
# ```
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[46], line 106
#     104 pdf_path = os.path.join(pdf_folder, pdf_file)
#     105 pdf_text = extract_text_from_pdf(pdf_path)
# --> 106 entries = generate_entries_from_pdf_text(pdf_text)
#     107 print(entries)
#     108 json_output = f"{pdf_folder}{os.path.splitext(pdf_file)[0]}_entries.json"
#
# Cell In[46], line 91, in generate_entries_from_pdf_text(pdf_text)
#      88 print(response_part2)
#      90 # Merge the generated JSON entries
# ---> 91 generated_entries_part1 = json.loads(response_part1)
#      92 generated_entries_part2 = json.loads(response_part2)
#      93 merged_entries = generated_entries_part1 + generated_entries_part2
#
# File d:\Envs\envs\cudaenv\lib\json\__init__.py:357, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352     del kw['encoding']
#     354 if (cls is None and object_hook is None and
#     355         parse_int is None and parse_float is None and
#     356         parse_constant is None and object_pairs_hook is None and not kw):
# --> 357     return _default_decoder.decode(s)
#     358 if cls is None:
#     359     cls = JSONDecoder
#
# File d:\Envs\envs\cudaenv\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File d:\Envs\envs\cudaenv\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
myresponse = """json
[
    {
        "question": "Quels sont les symptômes de la rhombencéphalite dans le cadre de la neurolistériose?",
        "answer": "La rhombencéphalite se traduit par des troubles de la vigilance, des convulsions et des déficits par atteinte des fibres longues, surtout des derniers nerfs crâniens.",
        "qtype": "symptômes"
    },
    {
        "question": "Quel est le traitement recommandé pour la listériose de la femme enceinte (méningite exclue)?",
        "answer": "Le traitement recommandé est l'amoxicilline (100 mg/kg/j) ou l'ampicilline pendant 2 à 3 semaines. Un aminoside est généralement déconseillé, mais dans les formes sévères, la gentamicine peut être donnée pendant 3 à 5 jours.",
        "qtype": "traitement"
    }
]
"""
